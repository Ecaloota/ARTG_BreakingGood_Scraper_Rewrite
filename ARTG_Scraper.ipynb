# %% [markdown]
# # ARTG Scraper Rewrite
#
# Recently, I wrote a scraper for the "Breaking Good" project (hereafter BG), a project which aims to collect information about the accessibility and availability of medicines classified as "essential" by the W.H.O.
#
# At the time, I had written the tool using Selenium - largely because I had little experience with BeautifulSoup, and I found it relatively-easy to implement automated file downloads using the former. Having now spent a bit of time getting aquainted with the latter, and because I am right now on holiday and the scope of the scraper requirements is clearer, I figured it might be time to re-visit the project, for fun, and to see if I can glean any new insights from the data.

# %% [markdown]
# ## Loading Data and Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import pdfplumber
import re
import time
import urllib3
import io

# %%
## Load the original CSV of essential medicine names
essential_medicine_names = pd.read_csv(f"WHO_essential_anti_infective_medicines.csv", header=None)

## what is the dimensionality of the longest search string? (We will need it later)
essential_medicine_names_split = pd.concat([essential_medicine_names[0].str.split(', ', expand=True)], axis=1)
essential_medicine_names_split.head()
num_cols = essential_medicine_names_split.shape[1] ## in this case, 4

## get rows where column 3 is not None (just to see)
non_none = essential_medicine_names_split.loc[essential_medicine_names_split[num_cols-1].notnull(), [i for i in range(0,num_cols)]]
#non_none.head()

# %% [markdown]
# ## Boilerplate Functions

# %%
def formatted_active_ingredient_string(input_string):
    '''
    Receives a comma-separated string of non-zero length containing medicine names:
    "abacavir" OR "abacavir, lamivudine" etc.
    Returns a formatted string for the meta_A tag on the TGA search client url:
    "abacavir" OR "abacavir%2C+lamivudine"
    
    If an empty string is given as input, function returns 0.
    '''

    ## convert string to list
    input_string = input_string.split(',')
    
    ## first active ingredient is first element
    actives = str(input_string[0])
    
    ## if there is more than one active ingredient, append it to formatted string
    if len(input_string) > 1:
        for ing in [str(ing.lstrip()) for ing in input_string[1:]]:
            actives+="%2C+"+str(ing)
    
    return actives


def artg_search(*args, **kwargs):
    '''
    Performs a search of the ARTG, in two modes. First, if a formatted ingredient string is passed
    from formatted_active_ingredient_string and a start_rank integer is also passed, we are 
    running a search of the ARTG on the main database page. Otherwise, if we receive only
    a valid ARTG identifier, we are running a sub-search of the database for a particular medicine.
    These two modes have different URLs, and will return Soup objects that need to be parsed differently.
    
    Returns a BeautifulSoup object.
    '''
    
    if "formatted_string" in kwargs and "start_rank" in kwargs:
        url = f"https://tga-search.clients.funnelback.com/s/search.html?from-advanced=true&collection=tga-artg&meta_A={kwargs['formatted_string']}&fmo=on&start_rank={kwargs['start_rank']}"
    elif "artg_id" in kwargs:
        url = f"https://tga-search.clients.funnelback.com/s/search.html?collection=tga-artg&profile=record&meta_i={kwargs['artg_id']}"
    else: return 0
    
    ## check status code is 200
    req = requests.get(url)
    if req.status_code != 200:
        return 0
    
    return BeautifulSoup(req.text, 'lxml')


def read_pdf_from_url(url):
    '''
    Code taken from Demian Wolf @ 
    https://stackoverflow.com/questions/62075033/read-pdf-from-url-to-memory-omitting-saving-file-to-local-file &&
    '''
    http = urllib3.PoolManager()
    temp = io.BytesIO()
    temp.write(http.request("GET", url).data)

    all_text = '' # new line
    with pdfplumber.open(temp) as pdf:
        
        for pdf_page in pdf.pages:
            
            # separate each page's text with newline
            single_page_text = pdf_page.extract_text()
            all_text = all_text + '\n' + single_page_text
            
    return all_text


def get_ARTG_data_from_string(query_string, category):
    '''
    Does what it says on the box. Receives a query_string (ideally, the PDF contents from read_pdf_from_url)
    and returns a match for "category XXX", where XXX is the value of category, if it exists.
    '''
    
    date_matches = ["Start Date", "Effective Date"]
    pair_matches = ["Dosage Form", "Route of Administration", "Status"]
    
    match_string = ""
    if category in date_matches:
        match_string = f"({category}) (\d+/\d+/\d+)"
    elif category in pair_matches:
        match_string = f"({category}) (.+)"
    else:
        return np.nan
    
    matches = re.findall(match_string, query_string)
    
    copy = []
    for match in matches:
        if not match[1] == '':
            copy.append(match)

    x = [tuple([k[0].lower().strip(), k[1]]) for k in copy]
    
    value = [i[1] for i in list(x)]

    return value


def get_number_of_subsearches(soup):
    '''
    Receives a beautifulsoup object. Finds the "description" class, and returns substrings that
    match the regex string.
    
    Check that search returned zero partial matches, and use the first group to define 
    the number of sub-searches we need to make (due to pagination).
    '''
    
    description_string = soup.find("p", {"class": "description"}).text
    match = re.search(r'Documents: (\d+) fully matching plus (\d+) partially matching', description_string)
    
    return int(match.group(1)), int(match.group(2))


def convert_profile_table(medicine, ID_string, profile_soup):
    '''
    Extract information from the profile information page. Namely, if there is a Public Summary document,
    extract additional information from parsing it.
    '''
    
    ## get the profile table into a dict; initialise the table with known ID; init variables
    public_summary_data_OI = ["Start Date", "Dosage Form", "Route of Administration", "Effective Date", "Status"]
    keys_not_of_interest = ["Product Information", "Public ARTG summary", "Consumer Medicines Information", "ARTG entry for"]
    table_dict = {"ARTG ID": int(ID_string),
                  "Search String": medicine}
    table = profile_soup.find('table')
    
    for row in table.findAll('tr'):
        if row.find('th').text == "Public ARTG summary":
            table_dict[row.find('th').text] = row.find('a')['href']
        else:
            table_dict[row.find('th').text] = [row.find('td').text]
            
    if table_dict["Public ARTG summary"]:
        public_summary_text = read_pdf_from_url(table_dict["Public ARTG summary"])
        
        for datum in public_summary_data_OI:
            table_dict[datum] = get_ARTG_data_from_string(public_summary_text, datum)
            
        if table_dict["Active ingredients"]:
            for ingredient_list in table_dict["Active ingredients"]:
                if len(medicine.split(',')) != len(ingredient_list.split(',')):
                    return None
                for index, ingredient in enumerate(ingredient_list.split(',')):
                    table_dict[f"Ingredient {index+1}"], table_dict[f"Ingredient {index+1} strength"] = get_ingredients_and_strengths_from_PDF(public_summary_text, ingredient)

    for key in keys_not_of_interest:
        table_dict.pop(key, None)

    ## some elements are lists, so we need to return by index and then transpose
    return pd.DataFrame.from_dict(table_dict, orient='index').transpose()


def get_ingredients_and_strengths_from_PDF(soup, ingredient):
    '''
    This will regex for "ingredient" in "soup".
    '''
    
    ## we assume strength units will only contain the characters m,g, and l, for milli, grams, and litres.
    search_string = f"({ingredient}\ *)([0-9]*\.?[0-9]*\ *[mgl]*\ *\/*[0-9]*[mgl]*(?<!/))"
    matches = re.findall(search_string, soup, flags = re.I)

    copy = []
    for match in matches:
        if not match[1] == '':
            copy.append(match)

    x = [tuple([k[0].lower().strip(), "".join(k[1].split())]) for k in copy]
    
    ingredient = list(set([i[0] for i in list(set(x))]))
    strength = list(set([i[1] for i in list(set(x))]))
    
    return ingredient, strength

# %% [markdown]
# ## Data Extraction

# %%
out_df = pd.DataFrame()

for i in range(len(essential_medicine_names)):
    rank = 1
    medicine = essential_medicine_names.iloc[i, 0]
    f_string = formatted_active_ingredient_string(medicine)
    ini_soup = artg_search(formatted_string=f_string, start_rank=rank)
    
    full_matches, partial_matches = get_number_of_subsearches(ini_soup)
    if partial_matches != 0 or full_matches == 0:
        continue
    
    while rank < full_matches:

        ## get the results page
        soup = artg_search(formatted_string=f_string, start_rank=rank)
        
        ## find all identifiers on the page
        ARTD_ID_list = [x.text for x in soup.findAll('li') if 'ARTG ID:' in str(x.text)]
        
        ## for each ID, run a profile search
        for ID_fullstring in ARTD_ID_list:
            
            ID_string = re.search(r'\d+', ID_fullstring).group(0)
            profile_soup = artg_search(artg_id=ID_string)
            current_df = convert_profile_table(medicine, ID_string, profile_soup)
            if current_df is not None:
                out_df = out_df.append(current_df, ignore_index=True)
                out_df.to_csv('out.csv')
        
        rank += 10 ## pagination increment by 10
        print(f"Getting soup for medicine: {medicine}; nmeds: {full_matches}, rank: {rank}")
# Out:
# Getting soup for medicine: abacavir; nmeds: 25, rank: 11
# Getting soup for medicine: abacavir; nmeds: 25, rank: 21
# Getting soup for medicine: abacavir; nmeds: 25, rank: 31
# Getting soup for medicine: abacavir, lamivudine; nmeds: 23, rank: 11
# Getting soup for medicine: abacavir, lamivudine; nmeds: 23, rank: 21
# Getting soup for medicine: abacavir, lamivudine; nmeds: 23, rank: 31
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 11
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 21
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 31
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 41
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 51
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 61
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 71
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 81
# Getting soup for medicine: aciclovir; nmeds: 90, rank: 91
# Getting soup for medicine: albendazole; nmeds: 4, rank: 11
# Getting soup for medicine: amikacin; nmeds: 8, rank: 11
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 11
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 21
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 31
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 41
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 51
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 61
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 71
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 81
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 91
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 101
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 111
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 121
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 131
# Getting soup for medicine: amoxicillin; nmeds: 140, rank: 141
# Getting soup for medicine: amoxicillin, clavulanic acid; nmeds: 3, rank: 11
# Getting soup for medicine: amphotericin B; nmeds: 3, rank: 11
# Getting soup for medicine: ampicillin; nmeds: 9, rank: 11
# Getting soup for medicine: artemether; nmeds: 4, rank: 11
# Getting soup for medicine: artemether, lumefantrine; nmeds: 4, rank: 11
# Getting soup for medicine: atazanavir; nmeds: 40, rank: 11
# Getting soup for medicine: atazanavir; nmeds: 40, rank: 21
# Getting soup for medicine: atazanavir; nmeds: 40, rank: 31
# Getting soup for medicine: atazanavir; nmeds: 40, rank: 41
# Getting soup for medicine: azithromycin; nmeds: 19, rank: 11
# Getting soup for medicine: azithromycin; nmeds: 19, rank: 21
# Getting soup for medicine: benzathine benzylpenicillin; nmeds: 2, rank: 11
# Getting soup for medicine: benzylpenicillin; nmeds: 11, rank: 11
# Getting soup for medicine: cefalexin; nmeds: 44, rank: 11
# Getting soup for medicine: cefalexin; nmeds: 44, rank: 21
# Getting soup for medicine: cefalexin; nmeds: 44, rank: 31
# Getting soup for medicine: cefalexin; nmeds: 44, rank: 41
# Getting soup for medicine: cefalexin; nmeds: 44, rank: 51
# Getting soup for medicine: cefazolin; nmeds: 16, rank: 11
# Getting soup for medicine: cefazolin; nmeds: 16, rank: 21
# Getting soup for medicine: cefotaxime; nmeds: 6, rank: 11
# Getting soup for medicine: ceftazidime; nmeds: 20, rank: 11
# Getting soup for medicine: ceftazidime; nmeds: 20, rank: 21
# Getting soup for medicine: ceftriaxone; nmeds: 33, rank: 11
# Getting soup for medicine: ceftriaxone; nmeds: 33, rank: 21
# Getting soup for medicine: ceftriaxone; nmeds: 33, rank: 31
# Getting soup for medicine: ceftriaxone; nmeds: 33, rank: 41
# Getting soup for medicine: cefuroxime; nmeds: 18, rank: 11
# Getting soup for medicine: cefuroxime; nmeds: 18, rank: 21
# Getting soup for medicine: chloramphenicol; nmeds: 19, rank: 11
# Getting soup for medicine: chloramphenicol; nmeds: 19, rank: 21
# Getting soup for medicine: ciprofloxacin; nmeds: 80, rank: 11
# Getting soup for medicine: ciprofloxacin; nmeds: 80, rank: 21
# Getting soup for medicine: ciprofloxacin; nmeds: 80, rank: 31
# Getting soup for medicine: ciprofloxacin; nmeds: 80, rank: 41
# Getting soup for medicine: ciprofloxacin; nmeds: 80, rank: 51
# Getting soup for medicine: ciprofloxacin; nmeds: 80, rank: 61
# Getting soup for medicine: ciprofloxacin; nmeds: 80, rank: 71
# Getting soup for medicine: ciprofloxacin; nmeds: 80, rank: 81
# Getting soup for medicine: clarithromycin; nmeds: 25, rank: 11
# Getting soup for medicine: clarithromycin; nmeds: 25, rank: 21
# Getting soup for medicine: clarithromycin; nmeds: 25, rank: 31
# Getting soup for medicine: clindamycin; nmeds: 23, rank: 11
# Getting soup for medicine: clindamycin; nmeds: 23, rank: 21
# Getting soup for medicine: clindamycin; nmeds: 23, rank: 31
# Getting soup for medicine: clofazimine; nmeds: 2, rank: 11
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 11
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 21
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 31
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 41
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 51
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 61
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 71
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 81
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 91
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 101
# Getting soup for medicine: clotrimazole; nmeds: 102, rank: 111
# Getting soup for medicine: daclatasvir; nmeds: 2, rank: 11
# Getting soup for medicine: dapsone; nmeds: 4, rank: 11
# Getting soup for medicine: darunavir; nmeds: 11, rank: 11
# Getting soup for medicine: dolutegravir; nmeds: 7, rank: 11
# Getting soup for medicine: doxycycline; nmeds: 47, rank: 11
# Getting soup for medicine: doxycycline; nmeds: 47, rank: 21
# Getting soup for medicine: doxycycline; nmeds: 47, rank: 31
# Getting soup for medicine: doxycycline; nmeds: 47, rank: 41
# Getting soup for medicine: doxycycline; nmeds: 47, rank: 51
# Getting soup for medicine: efavirenz; nmeds: 12, rank: 11
# Getting soup for medicine: efavirenz; nmeds: 12, rank: 21
# Getting soup for medicine: efavirenz, emtricitabine, tenofovir; nmeds: 2, rank: 11
# Getting soup for medicine: emtricitabine, tenofovir; nmeds: 26, rank: 11
# Getting soup for medicine: emtricitabine, tenofovir; nmeds: 26, rank: 21
# Getting soup for medicine: emtricitabine, tenofovir; nmeds: 26, rank: 31
# Getting soup for medicine: entecavir; nmeds: 66, rank: 11
# Getting soup for medicine: entecavir; nmeds: 66, rank: 21
# Getting soup for medicine: entecavir; nmeds: 66, rank: 31
# Getting soup for medicine: entecavir; nmeds: 66, rank: 41
# Getting soup for medicine: entecavir; nmeds: 66, rank: 51
# Getting soup for medicine: entecavir; nmeds: 66, rank: 61
# Getting soup for medicine: entecavir; nmeds: 66, rank: 71
# Getting soup for medicine: ethambutol; nmeds: 2, rank: 11
# Getting soup for medicine: fluconazole; nmeds: 75, rank: 11
# Getting soup for medicine: fluconazole; nmeds: 75, rank: 21
# Getting soup for medicine: fluconazole; nmeds: 75, rank: 31
# Getting soup for medicine: fluconazole; nmeds: 75, rank: 41
# Getting soup for medicine: fluconazole; nmeds: 75, rank: 51
# Getting soup for medicine: fluconazole; nmeds: 75, rank: 61
# Getting soup for medicine: fluconazole; nmeds: 75, rank: 71
# Getting soup for medicine: fluconazole; nmeds: 75, rank: 81
# Getting soup for medicine: gentamicin; nmeds: 9, rank: 11
# Getting soup for medicine: glecaprevir, pibrentasvir; nmeds: 2, rank: 11
# Getting soup for medicine: griseofulvin; nmeds: 2, rank: 11
# Getting soup for medicine: isoniazid; nmeds: 2, rank: 11
# Getting soup for medicine: itraconazole; nmeds: 14, rank: 11
# Getting soup for medicine: itraconazole; nmeds: 14, rank: 21
# Getting soup for medicine: ivermectin; nmeds: 3, rank: 11
# Getting soup for medicine: lamivudine; nmeds: 50, rank: 11
# Getting soup for medicine: lamivudine; nmeds: 50, rank: 21
# Getting soup for medicine: lamivudine; nmeds: 50, rank: 31
# Getting soup for medicine: lamivudine; nmeds: 50, rank: 41
# Getting soup for medicine: lamivudine; nmeds: 50, rank: 51
# Getting soup for medicine: lamivudine, zidovudine; nmeds: 6, rank: 11
# Getting soup for medicine: levofloxacin; nmeds: 2, rank: 11
# Getting soup for medicine: linezolid; nmeds: 53, rank: 11
# Getting soup for medicine: linezolid; nmeds: 53, rank: 21
# Getting soup for medicine: linezolid; nmeds: 53, rank: 31
# Getting soup for medicine: linezolid; nmeds: 53, rank: 41
# Getting soup for medicine: linezolid; nmeds: 53, rank: 51
# Getting soup for medicine: linezolid; nmeds: 53, rank: 61
# Getting soup for medicine: lopinavir, ritonavir; nmeds: 3, rank: 11
# Getting soup for medicine: mebendazole; nmeds: 18, rank: 11
# Getting soup for medicine: mebendazole; nmeds: 18, rank: 21
# Getting soup for medicine: meropenem; nmeds: 24, rank: 11
# Getting soup for medicine: meropenem; nmeds: 24, rank: 21
# Getting soup for medicine: meropenem; nmeds: 24, rank: 31
# Getting soup for medicine: metronidazole; nmeds: 23, rank: 11
# Getting soup for medicine: metronidazole; nmeds: 23, rank: 21
# Getting soup for medicine: metronidazole; nmeds: 23, rank: 31
# Getting soup for medicine: moxifloxacin; nmeds: 9, rank: 11
# Getting soup for medicine: nevirapine; nmeds: 13, rank: 11
# Getting soup for medicine: nevirapine; nmeds: 13, rank: 21
# Getting soup for medicine: nitrofurantoin; nmeds: 12, rank: 11
# Getting soup for medicine: nitrofurantoin; nmeds: 12, rank: 21
# Getting soup for medicine: nystatin; nmeds: 21, rank: 11
# Getting soup for medicine: nystatin; nmeds: 21, rank: 21
# Getting soup for medicine: oseltamivir; nmeds: 16, rank: 11
# Getting soup for medicine: oseltamivir; nmeds: 16, rank: 21
# Getting soup for medicine: pentamidine; nmeds: 3, rank: 11
# Getting soup for medicine: phenoxymethylpenicillin; nmeds: 19, rank: 11
# Getting soup for medicine: phenoxymethylpenicillin; nmeds: 19, rank: 21
# Getting soup for medicine: piperacillin, tazobactam; nmeds: 13, rank: 11
# Getting soup for medicine: piperacillin, tazobactam; nmeds: 13, rank: 21
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 11
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 21
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 31
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 41
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 51
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 61
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 71
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 81
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 91
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 101
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 111
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 121
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 131
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 141
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 151
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 161
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 171
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 181
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 191
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 201
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 211
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 221
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 231
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 241
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 251
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 261
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 271
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 281
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 291
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 301
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 311
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 321
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 331
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 341
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 351
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 361
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 371
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 381
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 391
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 401
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 411
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 421
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 431
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 441
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 451
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 461
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 471
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 481
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 491
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 501
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 511
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 521
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 531
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 541
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 551
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 561
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 571
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 581
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 591
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 601
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 611
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 621
# Getting soup for medicine: potassium iodide; nmeds: 624, rank: 631
# Getting soup for medicine: procaine benzylpenicillin; nmeds: 2, rank: 11
# Getting soup for medicine: proguanil; nmeds: 3, rank: 11
# Getting soup for medicine: pyrantel; nmeds: 5, rank: 11
# Getting soup for medicine: pyrimethamine; nmeds: 2, rank: 11
# Getting soup for medicine: quinine; nmeds: 4, rank: 11
# Getting soup for medicine: raltegravir; nmeds: 4, rank: 11
# Getting soup for medicine: ribavirin; nmeds: 3, rank: 11
# Getting soup for medicine: rifampicin; nmeds: 7, rank: 11
# Getting soup for medicine: ritonavir; nmeds: 4, rank: 11
# Getting soup for medicine: sofosbuvir; nmeds: 4, rank: 11
# Getting soup for medicine: sofosbuvir, velpatasvir; nmeds: 2, rank: 11
# Getting soup for medicine: sulfadiazine; nmeds: 2, rank: 11
# Getting soup for medicine: sulfamethoxazole, trimethoprim; nmeds: 10, rank: 11
# Getting soup for medicine: tenofovir disoproxil fumarate; nmeds: 35, rank: 11
# Getting soup for medicine: tenofovir disoproxil fumarate; nmeds: 35, rank: 21
# Getting soup for medicine: tenofovir disoproxil fumarate; nmeds: 35, rank: 31
# Getting soup for medicine: tenofovir disoproxil fumarate; nmeds: 35, rank: 41
# Getting soup for medicine: valganciclovir; nmeds: 23, rank: 11
# Getting soup for medicine: valganciclovir; nmeds: 23, rank: 21
# Getting soup for medicine: valganciclovir; nmeds: 23, rank: 31
# Getting soup for medicine: vancomycin; nmeds: 14, rank: 11
# Getting soup for medicine: vancomycin; nmeds: 14, rank: 21
# Getting soup for medicine: voriconazole; nmeds: 81, rank: 11
# Getting soup for medicine: voriconazole; nmeds: 81, rank: 21
# Getting soup for medicine: voriconazole; nmeds: 81, rank: 31
# Getting soup for medicine: voriconazole; nmeds: 81, rank: 41
# Getting soup for medicine: voriconazole; nmeds: 81, rank: 51
# Getting soup for medicine: voriconazole; nmeds: 81, rank: 61
# Getting soup for medicine: voriconazole; nmeds: 81, rank: 71
# Getting soup for medicine: voriconazole; nmeds: 81, rank: 81
# Getting soup for medicine: zidovudine; nmeds: 10, rank: 11

# %% [markdown]
# ## Data Cleaning

# %%
## If out_df isn't in kernel cache, re-load it from output CSV. We shouldn't (ideally)
## lose any accurary with the save/re-load because we're not storing numerical data
out_df = pd.read_csv("out.csv", index_col=0)

# %%
## Operate on a safe copy
out_df_copy = out_df.copy(deep=True)

## Remove annoying characters
for column in out_df_copy.columns[1:]:
    out_df_copy[column] = out_df_copy[column].str.strip("[]").str.replace("'", "")

out_df_copy.head()
# Out:
#    ARTG ID         Search String  \
# 0    66879              abacavir
# 1    66878              abacavir
# 2    99090  abacavir, lamivudine
# 3   296702  abacavir, lamivudine
# 4   296381  abacavir, lamivudine
#
#                                         Product name  \
# 0  ZIAGEN abacavir (as sulfate) 20mg/mL oral solu...
# 1  ZIAGEN abacavir (as sulfate) 300mg tablet blis...
# 2  KIVEXA abacavir 600 mg (as sulfate) and lamivu...
# 3  BEZORT abacavir 600mg (as sulfate) and lamivud...
# 4  ABACAVIR/LAMIVUDINE 600/300 SUN abacavir 600 m...
#
#             Active ingredients             Sponsor name  Start Date  \
# 0             abacavir sulfate  ViiV Healthcare Pty Ltd   9/06/1999
# 1             abacavir sulfate  ViiV Healthcare Pty Ltd   9/06/1999
# 2  abacavir sulfate,lamivudine  ViiV Healthcare Pty Ltd  24/03/2005
# 3  abacavir sulfate,lamivudine  ViiV Healthcare Pty Ltd  11/12/2017
# 4  abacavir sulfate,lamivudine   Sun Pharma ANZ Pty Ltd   5/09/2018
#
#              Dosage Form Route of Administration Effective Date  Status  \
# 0  Oral Liquid, solution                   Oral      25/01/2019  Active
# 1    Tablet, film coated                   Oral      25/01/2019  Active
# 2    Tablet, film coated                   Oral       6/06/2019  Active
# 3    Tablet, film coated                   Oral      11/12/2017  Active
# 4    Tablet, film coated                   Oral       5/09/2018  Active
#
#        Ingredient 1 Ingredient 1 strength Ingredient 2 Ingredient 2 strength  \
# 0  abacavir sulfate             23.4mg/mL          NaN                   NaN
# 1  abacavir sulfate                 351mg          NaN                   NaN
# 2  abacavir sulfate                 702mg   lamivudine                 300mg
# 3  abacavir sulfate                 702mg   lamivudine                 300mg
# 4  abacavir sulfate              702.78mg   lamivudine        600/300, 300mg
#
#   Ingredient 3 Ingredient 3 strength
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4          NaN                   NaN

# %%
## Find the rows in which we weren't able to find a 
## unique strength or ingredient identifier from the PDF

mask = (out_df_copy["Ingredient 1 strength"].str.split(",").str.len() > 1) | (out_df_copy["Ingredient 1"].str.split(",").str.len() > 1) | \
       (out_df_copy["Ingredient 2 strength"].str.split(",").str.len() > 1) | (out_df_copy["Ingredient 2"].str.split(",").str.len() > 1) | \
       (out_df_copy["Ingredient 3 strength"].str.split(",").str.len() > 1) | (out_df_copy["Ingredient 3"].str.split(",").str.len() > 1)

out_df_for_correction = out_df_copy.loc[mask] ## there are 325 with issues.
out_df_not_correction = out_df_copy.loc[~mask]

out_df_for_correction.to_csv("out_for_correction.csv")

# %%
out_df_corrected = pd.read_csv("out_for_correction.csv", index_col=0)
out_df_corrected = out_df_not_correction.append(out_df_corrected)

# %%
out_df_corrected.head()
# Out:
#     ARTG ID         Search String  \
# 0     66879              abacavir
# 1     66878              abacavir
# 2     99090  abacavir, lamivudine
# 3    296702  abacavir, lamivudine
# 21    99421             aciclovir
#
#                                          Product name  \
# 0   ZIAGEN abacavir (as sulfate) 20mg/mL oral solu...
# 1   ZIAGEN abacavir (as sulfate) 300mg tablet blis...
# 2   KIVEXA abacavir 600 mg (as sulfate) and lamivu...
# 3   BEZORT abacavir 600mg (as sulfate) and lamivud...
# 21  ACICLOVIR SANDOZ aciclovir 800mg tablet bliste...
#
#              Active ingredients             Sponsor name  Start Date  \
# 0              abacavir sulfate  ViiV Healthcare Pty Ltd   9/06/1999
# 1              abacavir sulfate  ViiV Healthcare Pty Ltd   9/06/1999
# 2   abacavir sulfate,lamivudine  ViiV Healthcare Pty Ltd  24/03/2005
# 3   abacavir sulfate,lamivudine  ViiV Healthcare Pty Ltd  11/12/2017
# 21                    aciclovir           Sandoz Pty Ltd   3/02/2004
#
#               Dosage Form Route of Administration Effective Date  Status  \
# 0   Oral Liquid, solution                   Oral      25/01/2019  Active
# 1     Tablet, film coated                   Oral      25/01/2019  Active
# 2     Tablet, film coated                   Oral       6/06/2019  Active
# 3     Tablet, film coated                   Oral      11/12/2017  Active
# 21       Tablet, uncoated                   Oral       7/06/2019  Active
#
#         Ingredient 1 Ingredient 1 strength Ingredient 2 Ingredient 2 strength  \
# 0   abacavir sulfate             23.4mg/mL          NaN                   NaN
# 1   abacavir sulfate                 351mg          NaN                   NaN
# 2   abacavir sulfate                 702mg   lamivudine                 300mg
# 3   abacavir sulfate                 702mg   lamivudine                 300mg
# 21         aciclovir                 800mg          NaN                   NaN
#
#    Ingredient 3 Ingredient 3 strength
# 0           NaN                   NaN
# 1           NaN                   NaN
# 2           NaN                   NaN
# 3           NaN                   NaN
# 21          NaN                   NaN

# %%
out_df_test["Ingredient 1 strength"].str.split(",")
# Out:
# 31        g,  500mg/20mL]
# 32        g,  250mg/10mL]
# 33                g/g,  5]
# 34                g/g,  5]
# 40      g/mL,  500mg/20mL]
#                  ...
# 1283               g,  G]
# 1284               g,  G]
# 1285                [G,  50mg]
# 1286                [G,  50mg]
# 1310      g/5mL,  10mg/mL]
# Name: Ingredient 1 strength, Length: 304, dtype: object
